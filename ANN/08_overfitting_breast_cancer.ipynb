# %% [markdown]
# # Checking The Overfitting
#
# - Breast Cancer Classification modeli adı verilen bir model geliştirilmiştir. İlgili mühendis bu modelin accuracy değerinin yüzde 98 olduğunu iddia etmektedir. Ancak modelin hastalarımız ile ilgili yaptığı yanlış tahminler hastanemizi sıkıntıya sokmaktadır :)
#
# - Bu modeli tekrar geliştiriniz ve sonuçları yorumlayınız.
#
# Logistic regression bölümünde elde ettiğimiz model accuracy değeri yüzde 98 idi. Bu durum bize aşırı öğrenme problemine düşebileceğimizi düşündürmüştü. Mühendisimizin günahını da alıyor olabiliriz. Bilmiyoruz.
#
# Bu sebeple aşırı öğrenme önlemleri alarak yeni bir model geliştirmemiz gerekiyor.
#
# Bu veri setini tekrar modelleyiniz.
#
# Dikkat edilmesi gerekenler:
#
# - sklearn içerisinde yer alan breast cancer veri setini kullanınız. (from sklearn.datasets import load_breast_cancer)
#
# - Veri ön işleme adımında amelasyon yapılabilir. Fonksiyon yazılmasına gerek yok.
#
# - Tensorflow dataset için tanımladığımız fonksiyonu kullanınız ve batch_size'ı 32 yapınız.
#
# - 1 gizli katmanlı basit bir model oluşturunuz. Nöron sayısını istediğiniz gibi tercih edebilirsiniz.
#
# - Aşırı öğrenme problemine karşı uygun katman yapılarını ve callback'i kullanınız.
#
# - Model compile bölümünde SGD'yi direkt kullanınız yani compile içinde optimizer="SGD" şeklinde kullanınız.
#
# - Overfitting'den şüphelendiğimiz için early stopping'de küçük bir değer giriniz.
#
# - En iyi epoch sonucunu yorumlayınız.
#
# - Loss eğrisini yorumlayınız.
#
# - İfade edilmeyen konularda tercih size bırakılmıştır.
#
# - Notebook'ta genel yapılar ve gidiş yolu için yönlendirmeler bırakılmıştır.

# %%
import keras
import tensorflow as tf
print("Keras Current Version:", keras.__version__, "Tensorflow Current Version:", tf.__version__)
# Out:
# Keras Current Version: 3.5.0 Tensorflow Current Version: 2.17.0

# %%
# !pip uninstall tf-keras

# %%
# !pip install tensorflow==2.16.1

# %% [markdown]
# # Imports and Settings

# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_breast_cancer


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.models import Sequential
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization

random.seed(46)
np.random.seed(46)
tf.random.set_seed(46)

# %% [markdown]
# # Functions

# %%
def plot_training_history(history, train_loss='loss', train_metric='accuracy', val_loss='val_loss', val_metric='val_accuracy'):
    plt.figure(figsize=(10, 5))
    plt.plot(history.history[train_loss], label='Training Loss')
    plt.plot(history.history[val_loss], label='Validation Loss')
    plt.title('Training and Validation Loss Over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

    plt.figure(figsize=(10, 5))
    plt.plot(history.history[train_metric], label=f"Training: {train_metric}")
    plt.plot(history.history[val_metric], label=f"Validation: {val_metric}")
    plt.title(f'Training and Validation {train_metric} Over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel(f'train_metric')
    plt.legend()
    plt.show()


def get_best_epoch_details(history):
    val_losses = history.history['val_loss']
    min_val_loss_index = val_losses.index(min(val_losses))
    best_epoch = min_val_loss_index + 1

    epoch_details = {}
    for key in history.history.keys():
        epoch_details[key] = history.history[key][min_val_loss_index]

    epoch_details['best_epoch'] = best_epoch
    return epoch_details

def prepare_datasets(X_train, X_val, y_train, y_val, batch_size=None):

    if batch_size is None:
        batch_size = len(X_train)

    train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
    train_dataset = train_dataset.shuffle(buffer_size=len(X_train)).batch(batch_size)
    val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val))
    val_dataset = val_dataset.batch(batch_size)

    return train_dataset, val_dataset

# %% [markdown]
# # Data Preprocess, Train Validation and Tensorflow Dataset

# %% [markdown]
# # Task 1: Veri setini yükleyiniz ve X ve y'yi alınız.

# %%
X,y = load_breast_cancer(return_X_y=True)

# %% [markdown]
# # Task 2: Train Validasyon seti ayrımını yapınız

# %%
x_train,x_val,y_train,y_val = train_test_split(X,y,random_state=42,test_size=0.2)

# %% [markdown]
# # Task 3: X_train ve X_val setlerini standart scaler'dan geçiriniz

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# # Task 4: Tensorflow Dataset oluşturunuz

# %%
train_ds, val_ds = prepare_datasets(x_train,x_val,y_train,y_val,batch_size=32)

# %% [markdown]
# # Model

# %% [markdown]
# # Task 5: Model yapısını aşırı öğrenme için uygun katmanları da kullanarak oluşturunuz

# %%
model = Sequential()
model.add(Input(shape=(train_ds.element_spec[0].shape[1],)))
model.add(Dense(32,activation="relu",kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(1,activation="sigmoid"))

# hoca 50 noron koymus ve dropout 0.5 belirlemis tek fark o

# %% [markdown]
# # Task 6: Modeli SGD ile, binary_crossentropy ve accuracy, AUC değerleri ile compile ediniz.

# %%
model.compile(optimizer="SGD",metrics=["accuracy","AUC"],loss="binary_crossentropy")

# %% [markdown]
# # Task 7: Early stopping callback'i tanımlayınız.

# %%
early_stopping = EarlyStopping(monitor="val_loss",patience=5,verbose=1,restore_best_weights=True)

# %% [markdown]
# # Task 8: Modeli train ediniz

# %%
history = model.fit(train_ds,epochs=1000,
                    validation_data=val_ds,verbose=1,
                    callbacks=early_stopping)
# Out:
# Epoch 1/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - AUC: 0.8610 - accuracy: 0.7664 - loss: 0.5175 - val_AUC: 0.9735 - val_accuracy: 0.8947 - val_loss: 0.4350
# Epoch 2/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9359 - accuracy: 0.8476 - loss: 0.3956 - val_AUC: 0.9836 - val_accuracy: 0.9035 - val_loss: 0.3776
# Epoch 3/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9639 - accuracy: 0.8945 - loss: 0.3319 - val_AUC: 0.9869 - val_accuracy: 0.9211 - val_loss: 0.3347
# Epoch 4/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9682 - accuracy: 0.9086 - loss: 0.3026 - val_AUC: 0.9898 - val_accuracy: 0.9386 - val_loss: 0.3042
# Epoch 5/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9762 - accuracy: 0.9237 - loss: 0.2633 - val_AUC: 0.9915 - val_accuracy: 0.9386 - val_loss: 0.2810
# Epoch 6/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.9807 - accuracy: 0.9288 - loss: 0.2493 - val_AUC: 0.9925 - val_accuracy: 0.9474 - val_loss: 0.2590
# Epoch 7/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9791 - accuracy: 0.9403 - loss: 0.2345 - val_AUC: 0.9938 - val_accuracy: 0.9474 - val_loss: 0.2443
# Epoch 8/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9668 - accuracy: 0.9160 - loss: 0.2664 - val_AUC: 0.9938 - val_accuracy: 0.9474 - val_loss: 0.2310
# Epoch 9/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.9878 - accuracy: 0.9627 - loss: 0.2048 - val_AUC: 0.9938 - val_accuracy: 0.9474 - val_loss: 0.2177
# Epoch 10/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9909 - accuracy: 0.9645 - loss: 0.1895 - val_AUC: 0.9941 - val_accuracy: 0.9474 - val_loss: 0.2062
# Epoch 11/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.9898 - accuracy: 0.9619 - loss: 0.1954 - val_AUC: 0.9946 - val_accuracy: 0.9474 - val_loss: 0.1959
# Epoch 12/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9826 - accuracy: 0.9449 - loss: 0.2088 - val_AUC: 0.9948 - val_accuracy: 0.9474 - val_loss: 0.1876
# Epoch 13/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - AUC: 0.9939 - accuracy: 0.9596 - loss: 0.1660 - val_AUC: 0.9948 - val_accuracy: 0.9561 - val_loss: 0.1804
# Epoch 14/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9876 - accuracy: 0.9420 - loss: 0.1868 - val_AUC: 0.9948 - val_accuracy: 0.9561 - val_loss: 0.1738
# Epoch 15/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9919 - accuracy: 0.9623 - loss: 0.1691 - val_AUC: 0.9949 - val_accuracy: 0.9561 - val_loss: 0.1682
# Epoch 16/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9926 - accuracy: 0.9637 - loss: 0.1651 - val_AUC: 0.9953 - val_accuracy: 0.9561 - val_loss: 0.1636
# Epoch 17/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.9877 - accuracy: 0.9494 - loss: 0.1852 - val_AUC: 0.9953 - val_accuracy: 0.9561 - val_loss: 0.1604
# Epoch 18/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9913 - accuracy: 0.9466 - loss: 0.1637 - val_AUC: 0.9951 - val_accuracy: 0.9649 - val_loss: 0.1566
# Epoch 19/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9905 - accuracy: 0.9530 - loss: 0.1720 - val_AUC: 0.9951 - val_accuracy: 0.9649 - val_loss: 0.1529
# Epoch 20/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9909 - accuracy: 0.9701 - loss: 0.1658 - val_AUC: 0.9951 - val_accuracy: 0.9649 - val_loss: 0.1498
# Epoch 21/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9892 - accuracy: 0.9517 - loss: 0.1724 - val_AUC: 0.9951 - val_accuracy: 0.9649 - val_loss: 0.1469
# Epoch 22/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9920 - accuracy: 0.9470 - loss: 0.1666 - val_AUC: 0.9954 - val_accuracy: 0.9649 - val_loss: 0.1442
# Epoch 23/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9953 - accuracy: 0.9684 - loss: 0.1406 - val_AUC: 0.9954 - val_accuracy: 0.9649 - val_loss: 0.1419
# Epoch 24/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9932 - accuracy: 0.9590 - loss: 0.1504 - val_AUC: 0.9957 - val_accuracy: 0.9649 - val_loss: 0.1391
# Epoch 25/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9961 - accuracy: 0.9687 - loss: 0.1358 - val_AUC: 0.9956 - val_accuracy: 0.9649 - val_loss: 0.1373
# Epoch 26/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9823 - accuracy: 0.9432 - loss: 0.1844 - val_AUC: 0.9956 - val_accuracy: 0.9649 - val_loss: 0.1352
# Epoch 27/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9949 - accuracy: 0.9670 - loss: 0.1412 - val_AUC: 0.9956 - val_accuracy: 0.9649 - val_loss: 0.1329
# Epoch 28/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9936 - accuracy: 0.9779 - loss: 0.1429 - val_AUC: 0.9957 - val_accuracy: 0.9649 - val_loss: 0.1310
# Epoch 29/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9921 - accuracy: 0.9632 - loss: 0.1480 - val_AUC: 0.9957 - val_accuracy: 0.9649 - val_loss: 0.1301
# Epoch 30/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9970 - accuracy: 0.9745 - loss: 0.1296 - val_AUC: 0.9957 - val_accuracy: 0.9649 - val_loss: 0.1286
# Epoch 31/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9966 - accuracy: 0.9748 - loss: 0.1210 - val_AUC: 0.9957 - val_accuracy: 0.9649 - val_loss: 0.1282
# Epoch 32/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9948 - accuracy: 0.9699 - loss: 0.1403 - val_AUC: 0.9961 - val_accuracy: 0.9649 - val_loss: 0.1269
# Epoch 33/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9959 - accuracy: 0.9746 - loss: 0.1276 - val_AUC: 0.9959 - val_accuracy: 0.9649 - val_loss: 0.1258
# Epoch 34/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9947 - accuracy: 0.9772 - loss: 0.1239 - val_AUC: 0.9959 - val_accuracy: 0.9649 - val_loss: 0.1253
# Epoch 35/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9919 - accuracy: 0.9538 - loss: 0.1506 - val_AUC: 0.9959 - val_accuracy: 0.9649 - val_loss: 0.1244
# Epoch 36/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9978 - accuracy: 0.9749 - loss: 0.1186 - val_AUC: 0.9961 - val_accuracy: 0.9649 - val_loss: 0.1234
# Epoch 37/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9873 - accuracy: 0.9615 - loss: 0.1585 - val_AUC: 0.9961 - val_accuracy: 0.9649 - val_loss: 0.1228
# Epoch 38/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9980 - accuracy: 0.9811 - loss: 0.1191 - val_AUC: 0.9961 - val_accuracy: 0.9649 - val_loss: 0.1218
# Epoch 39/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9960 - accuracy: 0.9716 - loss: 0.1295 - val_AUC: 0.9961 - val_accuracy: 0.9649 - val_loss: 0.1214
# Epoch 40/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9881 - accuracy: 0.9672 - loss: 0.1515 - val_AUC: 0.9959 - val_accuracy: 0.9649 - val_loss: 0.1213
# Epoch 41/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9945 - accuracy: 0.9643 - loss: 0.1315 - val_AUC: 0.9959 - val_accuracy: 0.9649 - val_loss: 0.1210
# Epoch 42/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9951 - accuracy: 0.9673 - loss: 0.1287 - val_AUC: 0.9961 - val_accuracy: 0.9649 - val_loss: 0.1198
# Epoch 43/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9977 - accuracy: 0.9784 - loss: 0.1168 - val_AUC: 0.9961 - val_accuracy: 0.9649 - val_loss: 0.1195
# Epoch 44/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9974 - accuracy: 0.9842 - loss: 0.1051 - val_AUC: 0.9961 - val_accuracy: 0.9649 - val_loss: 0.1184
# Epoch 45/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9961 - accuracy: 0.9696 - loss: 0.1211 - val_AUC: 0.9961 - val_accuracy: 0.9649 - val_loss: 0.1175
# Epoch 46/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9966 - accuracy: 0.9736 - loss: 0.1183 - val_AUC: 0.9961 - val_accuracy: 0.9649 - val_loss: 0.1169
# Epoch 47/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9972 - accuracy: 0.9843 - loss: 0.1077 - val_AUC: 0.9961 - val_accuracy: 0.9649 - val_loss: 0.1164
# Epoch 48/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9967 - accuracy: 0.9785 - loss: 0.1144 - val_AUC: 0.9961 - val_accuracy: 0.9649 - val_loss: 0.1161
# Epoch 49/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9967 - accuracy: 0.9719 - loss: 0.1128 - val_AUC: 0.9959 - val_accuracy: 0.9649 - val_loss: 0.1170
# Epoch 50/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9959 - accuracy: 0.9576 - loss: 0.1331 - val_AUC: 0.9957 - val_accuracy: 0.9649 - val_loss: 0.1166
# Epoch 51/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9960 - accuracy: 0.9627 - loss: 0.1161 - val_AUC: 0.9957 - val_accuracy: 0.9649 - val_loss: 0.1161
# Epoch 52/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9950 - accuracy: 0.9617 - loss: 0.1247 - val_AUC: 0.9957 - val_accuracy: 0.9649 - val_loss: 0.1159
# Epoch 53/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9971 - accuracy: 0.9731 - loss: 0.1201 - val_AUC: 0.9957 - val_accuracy: 0.9649 - val_loss: 0.1159
# Epoch 54/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9976 - accuracy: 0.9780 - loss: 0.1224 - val_AUC: 0.9957 - val_accuracy: 0.9737 - val_loss: 0.1156
# Epoch 55/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9937 - accuracy: 0.9537 - loss: 0.1388 - val_AUC: 0.9957 - val_accuracy: 0.9649 - val_loss: 0.1153
# Epoch 56/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9945 - accuracy: 0.9680 - loss: 0.1198 - val_AUC: 0.9957 - val_accuracy: 0.9649 - val_loss: 0.1156
# Epoch 57/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9978 - accuracy: 0.9799 - loss: 0.1046 - val_AUC: 0.9961 - val_accuracy: 0.9737 - val_loss: 0.1152
# Epoch 58/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9985 - accuracy: 0.9734 - loss: 0.1005 - val_AUC: 0.9957 - val_accuracy: 0.9737 - val_loss: 0.1153
# Epoch 59/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9958 - accuracy: 0.9604 - loss: 0.1172 - val_AUC: 0.9961 - val_accuracy: 0.9737 - val_loss: 0.1149
# Epoch 60/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9958 - accuracy: 0.9725 - loss: 0.1209 - val_AUC: 0.9961 - val_accuracy: 0.9737 - val_loss: 0.1144
# Epoch 61/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9981 - accuracy: 0.9762 - loss: 0.1064 - val_AUC: 0.9961 - val_accuracy: 0.9737 - val_loss: 0.1139
# Epoch 62/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9981 - accuracy: 0.9741 - loss: 0.1036 - val_AUC: 0.9961 - val_accuracy: 0.9737 - val_loss: 0.1142
# Epoch 63/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9966 - accuracy: 0.9802 - loss: 0.1039 - val_AUC: 0.9957 - val_accuracy: 0.9737 - val_loss: 0.1152
# Epoch 64/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9993 - accuracy: 0.9825 - loss: 0.0847 - val_AUC: 0.9957 - val_accuracy: 0.9737 - val_loss: 0.1148
# Epoch 65/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9969 - accuracy: 0.9765 - loss: 0.1144 - val_AUC: 0.9959 - val_accuracy: 0.9737 - val_loss: 0.1144
# Epoch 66/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.9956 - accuracy: 0.9775 - loss: 0.1159 - val_AUC: 0.9959 - val_accuracy: 0.9737 - val_loss: 0.1143
# Epoch 66: early stopping
# Restoring model weights from the end of the best epoch: 61.

# %% [markdown]
# # Task 9: En iyi epoch değerlerini getiriniz ve yorumlayınız.

# %%
# en iyi epoch değeri 61 diyor ancak getirmeye calısalım

# %%
get_best_epoch_details(history)
# en iyi epoch degerim 61 ve model sonuclarım da gayet iyi duruyor
# Out:
# {'AUC': 0.9974241852760315,
#  'accuracy': 0.9736263751983643,
#  'loss': 0.10862750560045242,
#  'val_AUC': 0.9960694909095764,
#  'val_accuracy': 0.9736841917037964,
#  'val_loss': 0.11394189298152924,
#  'best_epoch': 61}

# %% [markdown]
# # Task 10: Train history'sini görselleştiriniz ve yorumlayınız

# %%
plot_training_history(history)

# %%
# modelimiz iyi şekilde öğrenmiş val setinde de öğrenme iyi oldugu icin asırı ogrenme var diyemeyiz bence
# train işlemindeki dalgalanmaların sebebi aşırı öğrenmeyi engellemek için kullandığımız noron sondurme, 
# batchnormalization ile aktivasyonları normalleştirme,l2 duzgunlulestirmesi olabilir. bu bir sorun olarak gözükmüyor burada

# %% [markdown]
# # Task 11: Modelin aşırı öğrenme durumu ile ilgili ne düşünüyorsunuz?

# %%
# modelimizde aşırı öğrenme sorunu yoktur
